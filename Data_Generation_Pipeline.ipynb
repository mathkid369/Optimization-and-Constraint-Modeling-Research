# %%
import os
for k in ["http_proxy","https_proxy","HTTP_PROXY","HTTPS_PROXY"]:
    os.environ.pop(k, None)

# %%
#%pip install --upgrade openai
#%pip install --upgrade python-dotenv
#%pip install httpx

# %%
# Step 1: Extract the descriptions of the problems from the Text2Zinc GitHub repository

# %pip install datasets -q

from datasets import load_dataset
import json
import os
import random

# Step 1A: Load dataset

print("🔄 Loading Text2Zinc dataset...")
dataset = load_dataset("skadio/text2zinc")

all_descriptions = []

# Step 1B: Extract all problem descriptions

for split_name, split_data in dataset.items():
    print(f"\n📘 Processing split: {split_name}")
    print("Columns:", split_data.column_names)

    if "input.json" in split_data.column_names:
        for record in split_data["input.json"]:
            if isinstance(record, str):
                try:
                    record = json.loads(record)
                except json.JSONDecodeError:
                    continue

            if isinstance(record, dict) and "description" in record:
                all_descriptions.append(record["description"])
    else:
        print(f"⚠️ No 'input.json' column found in {split_name}")

print(f"\n📊 Total descriptions collected: {len(all_descriptions)}")

# Step 1C: Automatically sample N descriptions

m = 0 # Start point
n = 500  # End point
print(f"\n✅ Sampling {n} descriptions...\n")

if len(all_descriptions) < n:
    print(f"⚠️ Only {len(all_descriptions)} available, using all.")
    sampled_descriptions = all_descriptions
else:
    sampled_descriptions = all_descriptions[m:n]


#t Step 1D: Save to files

with open("descriptions.json", "w", encoding="utf-8") as f:
    json.dump(sampled_descriptions, f, indent=2)

with open("descriptions.txt", "w", encoding="utf-8") as f:
    for desc in sampled_descriptions:
        f.write(desc.strip().replace("\n", " ") + "\n\n")

print("💾 Saved 'descriptions.json' and 'descriptions.txt'")
print("\n📂 Files in current directory:", os.listdir())

print("\nExample description:\n", sampled_descriptions[0][:400])
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 🔄 Loading Text2Zinc dataset...
#
# 📘 Processing split: train
# Columns: ['input.json', 'data.dzn', 'model.mzn', 'output.json', 'is_verified']
#
# 📊 Total descriptions collected: 567
#
# ✅ Sampling 500 descriptions...
#
# 💾 Saved 'descriptions.json' and 'descriptions.txt'
#
# 📂 Files in current directory: ['.env', '.idea', '.venv', 'Data_Generation_Pipeline.ipynb', 'descriptions.json', 'descriptions.txt', 'generated_personas', 'generated_problems', 'generated_solutions', 'veritas-solutions.zip']
#
# Example description:
#  The P-Median problem involves selecting P warehouses from a set of candidate locations to minimize the demand-weighted distance of serving all customers. We are given the demand of customers and distances between customers and warehouses. Each customer is served by exactly one warehouse. The goal is to allocate warehouses to minimize the sum of demand weighted distances of the customers to the war

# %%
import os, json, time  
from pathlib import Path  
from dotenv import load_dotenv  
from openai import OpenAI  
import httpx
  
# Load env (adjust path as needed)  
load_dotenv()  
# Or: load_dotenv(r"C:\Users\0117422\PycharmProjects\veritas\.env", override=True)


AZURE_API_KEY = os.getenv("OPENAI_API_KEY")
AZURE_ENDPOINT = "https://oai-preprod-canadaeast-001.openai.azure.com" # your resource
API_VERSION = "" # example; use the version your resource supports
DEPLOYMENT_NAME = "gpt-5" # your Azure deployment name
  
if not (AZURE_ENDPOINT and AZURE_API_KEY and DEPLOYMENT_NAME):  
    raise RuntimeError("Missing one of AZURE_OPENAI_ENDPOINT, AZURE_OPENAI_API_KEY, or AZURE_OPENAI_DEPLOYMENT.")
  
# Only keep a custom client if you truly need it (e.g., corporate proxy/CA)  
http_client = httpx.Client(timeout=30.0)
  
client = OpenAI(  
    api_key=AZURE_API_KEY,  
    base_url=f"{AZURE_ENDPOINT}/openai/v1",          # note the /v1  
    default_query={"api-version": API_VERSION},      # Azure API version routing  
    http_client=http_client,  
)
  
# Load problem descriptions  
#with open("descriptions.txt", "r", encoding="cp1252") as f:  
#    descriptions = [line.strip() for line in f if line.strip()] 

with open("descriptions.json", "r",encoding="utf-8") as f:
    descriptions = json.load(f)
  
persona_prompt_template = """Develop a detailed, realistic persona relevant to the following problem description:

{description}

Focus the description on their occupation, incorporating how their professional background or responsibilities have led them to engage with the problem in a natural, contextual way.
Avoid generic phrases such as 'noticed' or 'began exploring.'
The persona should not include age or a specific name and must not restate the problem directly.
Ensure the background feels authentic and the connection to the problem is clearly rooted in their work or expertise.
Response must be at least 3 sentences in length in a narrative format. 
It should be exactly one paragraph long written in the most concise manner possible.  
"""
  
def prompt_chatgpt(prompt: str, model: str = DEPLOYMENT_NAME, temperature: float = 1) -> str:  
    # simple retry/backoff for throttling/transient faults  
    delay = 0.5  
    for attempt in range(6):  
        try:  
            resp = client.chat.completions.create(  
                model=model,  # IMPORTANT: this is your Azure deployment name  
                messages=[{"role": "user", "content": prompt}],  
                temperature=temperature,  
            )  
            return resp.choices[0].message.content  
        except Exception as e:  
            msg = str(e)  
            if any(code in msg for code in ("429", "503", "rate limit", "temporarily unavailable")) and attempt < 5:  
                time.sleep(delay)  
                delay = min(delay * 2, 8.0)  
                continue  
            raise
  
# Output directory  
output_dir = Path("generated_personas")  
output_dir.mkdir(parents=True, exist_ok=True)
  
personas = []  
for i, desc in enumerate(descriptions, start=1):  
    print(f"\n🔮 Generating persona {i} of {len(descriptions)}...\n")  
    prompt = persona_prompt_template.format(description=desc)  
    persona_text = prompt_chatgpt(prompt)  
    personas.append({"id": i, "description": desc, "persona": persona_text})  
    print(persona_text[:400], "...\n")
  
# Save results  
(output_dir / "personas.json").write_text(json.dumps(personas, indent=2), encoding="utf-8")  
with open(output_dir / "personas.txt", "w", encoding="utf-8") as f:  
    for p in personas:  
        f.write(f"=== Persona {p['id']} ===\n{p['persona']}\n\n")
  
print("\n✅ Successfully generated and saved all personas:")  
print(f"📂 {output_dir / 'personas.json'}")  
print(f"📂 {output_dir / 'personas.txt'}")
# Out:
# 🔮 Generating persona 1 of 500...
#
# A senior network planning analyst at an omnichannel retail chain, they lead the design of the distribution footprint that feeds hundreds of stores and parcel fulfillment nodes under strict service-level and capital constraints. With a background in operations research and carrier route engineering, they maintain a demand-by-location forecast, build travel-time matrices from carrier telemetry, and  ...
#
#
# 🔮 Generating persona 2 of 500...
#
# A municipal lighting engineer overseeing an adaptive LED retrofit on arterial roads, this professional is accountable for tuning dimming levels so corridor segments meet mandated illuminance classes while controlling energy spend and mitigating glare complaints. Using manufacturer photometry and a streetscape model, they assemble an influence matrix that quantifies how each luminaire contributes t ...
#
#
# 🔮 Generating persona 3 of 500...
#
# A refinery planning manager at a large integrated site, this professional translates market price decks and supply commitments into a monthly operating plan that aligns commercial goals with technical realities. With a background in chemical engineering and operations research, they maintain a linear optimization model of unit yields and variable processing costs across FCC, hydrocracker, reformer ...
#
#
# 🔮 Generating persona 4 of 500...
#
# An operations research engineer at a national air navigation service provider, they own the runway sequencing logic that feeds the arrival manager used by tower and approach controllers at a congested hub. Their remit blends safety and economics: encode wake turbulence separations, runway configuration changes, and crossing traffic while tuning cost functions that reflect airline delay exposure, c ...
#
#
# 🔮 Generating persona 5 of 500...
#
# A senior industrial planning economist at a national ministry, they lead the inter-industry optimization unit charged with translating sectoral procurement plans, stockpile policies, and labor ceilings into a coherent medium-term production strategy. Their work integrates input–output accounts with capacity build programs and known gestation lags, coordinating with energy, metals, chemicals, and t ...
#
#
# 🔮 Generating persona 6 of 500...
#
# A senior quality assurance engineer at a mobile studio that ships pixel-logic titles, this professional is responsible for validating that auto-generated grids are uniquely solvable and culminate in recognizable pixel art within targeted difficulty bands. They maintain an internal solver that enforces 3x3 adjacency counts including the center cell, stress-test edge and corner cases where constrain ...
#
#
# 🔮 Generating persona 7 of 500...
#
# A production planning manager at a multi-product manufacturer, this professional owns the master production schedule and profitability targets for lines constrained by machine capacity and warehouse limits. With training in industrial engineering and operations research, they turn sales commitments, machine routings, processing times, and planned maintenance outages into finite-capacity plans that ...
#
#
# 🔮 Generating persona 8 of 500...
#
# A puzzle editor at a national daily, trained in combinatorics and scripting, manages the pipeline for picture-logic grids with numeric edge hints that anchor the weekend games section. They developed tools to convert themed icons from the features desk into solvable, uniqueness-checked grids, calibrating difficulty to fit page layout constraints and reader time-on-page targets. Feedback and error  ...
#
#
# 🔮 Generating persona 9 of 500...
#
# A supply chain planning lead at an edible oils producer, they run the monthly S&OP that connects supplier contracts to refinery schedules and blend recipes under tight quality specifications. With a background in operations research and process engineering, they model blend hardness from component attributes, allocate vegetable and non‑vegetable streams across separate lines, and integrate storage ...
#
#
# 🔮 Generating persona 10 of 500...
#
# A network optimization manager at a mid-size airline, trained in operations research, translates demand forecasts and slot holdings into a viable seasonal schedule by selecting which fleet types serve specific city pairs. Using Python and CPLEX, they build mixed-integer models that reconcile aircraft rotations with runway performance, ETOPS qualifications, maintenance windows, crew duty rules, and ...
#
#
# 🔮 Generating persona 11 of 500...
#
# A STEM outreach coordinator for a public school district with a background in industrial engineering oversees the annual science fair’s operations, from capacity planning and floor layouts to compliance with fire codes and ADA access. Their role translates student registrations and project requirements into concrete furniture plans, reconciling table footprints with poster board allotments, electr ...
#
#
# 🔮 Generating persona 12 of 500...
#
# As the metallurgical process engineer at a specialty foundry, they own charge design and furnace economics for contract melts. Their daily work involves reconciling assay certificates for available ores and ferroalloys, mapping silicon and manganese contributions, and building blends that hit specified chemistry windows while honoring stock limits and melt-shop throughput. Partnering with procurem ...
#
#
# 🔮 Generating persona 13 of 500...
#
# A manufacturing systems technician responsible for keeping legacy CNC machines running under DOS routinely prepares recovery media for operators, since the controllers only accept floppy disks and store critical toolpaths as uncompressed files. With a maintenance freeze approaching during a planned absence, they need a compact, reliable set of backups that fits the plant’s strict inventory trackin ...
#
#
# 🔮 Generating persona 14 of 500...
#
# A lead operations research economist at a national industrial planning directorate, they design five-year sectoral programs using dynamic input–output tables and intertemporal linear programming to allocate scarce labor and cross-industry outputs between immediate demand and capacity formation with known maturation lags. They work with statistical agencies and industry associations to pin down tec ...
#
#
# 🔮 Generating persona 15 of 500...
#
# A quantitative portfolio engineer at a direct-indexing robo-advisor, this investor spends workdays designing tax-lot optimizers and execution logic that trade fractional shares, model percentage-based transaction costs, and minimize tax drag for clients’ taxable accounts. A personal requirement to fund an upcoming capital call in a private fund pushes that expertise into practice, drawing on inter ...
#
#
# 🔮 Generating persona 16 of 500...
#
# An industrial engineer leading the sales and operations planning team at a mid-sized edible oil company coordinates procurement with month-variable supplier price lists, schedules two refining lines segregated by vegetable and non-vegetable feedstocks, and architects blend recipes that satisfy a hardness specification enforced by QA and customer contracts. Their remit includes deciding what to buy ...
#
#
# 🔮 Generating persona 17 of 500...
#
# A maritime surveillance systems engineer tasked with building grid-based inference tools for coastal defense, they routinely convert sparse radar and AIS returns into plausible vessel layouts while enforcing separation rules and platform composition limits. The puzzle maps cleanly onto their workflow: sector totals resemble row and column aggregates used in load monitoring, and each confirmed cont ...
#
#
# 🔮 Generating persona 18 of 500...
#
# An operations planner at a mid-volume electronics plant, trained in industrial engineering and cost accounting, owns the daily build schedule and gross-margin targets. Years of time studies and lab throughput tracking provide precise hour-per-unit standards for assembly and test, while a union agreement caps regular and overtime hours the team can deploy. Procurement relies on this role to shape p ...
#
#
# 🔮 Generating persona 19 of 500...
#
# As the Scheduling and Optimization Lead for a regional transit authority coordinating multiple contracted bus companies, they design driver rosters across depots with disparate union rules, meal-break constraints, and minimum duty guarantees. With an operations research background and dispatcher experience, they maintain a vetted library of feasible duties, ingest daily block lists from the timeta ...
#
#
# 🔮 Generating persona 20 of 500...
#
# A labor market planner at a national industry ministry, responsible for a five-year employment absorption program, works with detailed inter-industry coefficients, bill-of-materials structures, and training pipelines to translate production schedules into labor hour requirements. Their mandate is to drive job creation while meeting consumption commitments, so they orchestrate the timing of product ...
#
#
# 🔮 Generating persona 21 of 500...
#
# As the school district’s Manager of Enrollment Planning and GIS, they oversee annual attendance boundary reviews, grade-level seat inventories, and coordination with Transportation on routing and budget impacts. With an operations research background, they built a network optimization that treats neighborhood enrollment forecasts as flows and school capacities as grade-specific constraints, using  ...
#
#
# 🔮 Generating persona 22 of 500...
#
# An array signal-processing engineer at a radar firm designs sparse linear sensor arrays for compact maritime platforms, where every sensor pair must yield a unique baseline to avoid angle-of-arrival ambiguities. With tight limits on mast length and weight, they frame the placement problem as an integer model and seek Golomb ruler layouts that minimize total span for a fixed sensor count while pres ...
#
#
# 🔮 Generating persona 23 of 500...
#
# A transport operations analyst for an Italian intermodal carrier managing the Po River and canal network, responsible for repositioning empty containers from inland depots to seaports to meet sailing windows and service-level commitments. Their work reconciles daily inventory reports with minimum safety stocks at each depot, schedules two-slot barge charters under a per‑kilometer tariff, and align ...
#
#
# 🔮 Generating persona 24 of 500...
#
# An operations planner for a metropolitan hospital’s food services department, accountable for labor budgeting, union compliance, and service-level targets across multiple cafeterias. Using POS data, patient census, and clinic timetables, they forecast the headcount required each day and then build cyclic rosters because the collective agreement mandates each attendant to work a set block of consec ...
#
#
# 🔮 Generating persona 25 of 500...
#
# A quantitative developer on an FX execution desk at a proprietary trading firm, they build and maintain the engine that routes orders across multiple liquidity venues and optimizes multi-currency conversion paths under capital, latency, and fee constraints. Portfolio mandates emphasize short holding periods and market-neutral strategies, so their model design centers on rapid identification of pro ...
#
#
# 🔮 Generating persona 26 of 500...
#
# A marine logistics planner for an offshore supply fleet, I produce deck stowage plans for back-to-back sailings to platforms, balancing cargo capacity, HSE segregation rules (IMDG, NORSOK), and crane sequencing. Manifests mix chemicals, brine tanks, dry bulk, and gas racks with class-based distances that differ longitudinally and transversely, and every unit must be single-tier and aligned to the  ...
#
#
# 🔮 Generating persona 27 of 500...
#
# An electrical engineer responsible for electrostatic control in high-density touch interfaces models steady-state potential across the sensor array using a discrete r-by-c grid whose edge values come from measured fixtures and are constrained between Z and M to reflect allowable operating limits. To synthesize shielding layouts and ground tie placements, the engineer enforces a harmonic interior w ...
#
#
# 🔮 Generating persona 28 of 500...
#
# A route optimization analyst for a regional grocery e-commerce network, they design daily plans for multiple cross-docks, aligning driver shifts, truck payload and refrigerated capacity with customer delivery windows and expected stop durations. They build and maintain travel-time matrices from telematics data, calibrate service-time distributions by order type, and tune routing logic to reduce ov ...
#
#
# 🔮 Generating persona 29 of 500...
#
# The production planning and optimization lead at a hygiene manufacturer translates procurement’s weekly ethanol allocations and municipal water caps into feasible batch schedules across foam and liquid sanitizer lines. Trained as an industrial engineer with experience in linear programming for FMCG plants, they build models that convert ingredient use and fill volumes into a coverage KPI—hands san ...
#
#
# 🔮 Generating persona 30 of 500...
#
# A process engineer at a national mint, they own the weekly plating schedule for commemorative coin runs. Two production lines with distinct bath chemistry profiles draw gold and consume wiring harnesses at different rates, and procurement imposes tight caps on precious metal withdrawals while maintenance limits available leads. Their remit is to translate these constraints into an executable mix o ...
#
#
# 🔮 Generating persona 31 of 500...
#
# He runs a small, lake-licensed commercial skiff and handles everything from gear planning to meeting a processor’s daily weight target. Bait is rationed by his supplier, his permit caps the acres he can touch, and a chronic shoulder flare-up forces him to budget exertion using a pain scale cleared by his physiotherapist. He grids the lake into acre blocks, marking where baited trap nets can sweep  ...
#
#
# 🔮 Generating persona 32 of 500...
#
# An operations research specialist embedded in a humanitarian airlift unit, this professional designs drop patterns for cargo planes when roads are impassable. Their daily work merges satellite settlement extracts with UAV reconnaissance to build grid-based demand maps, then applies two-facility location modeling and k-means style clustering with squared-distance cost to reflect the accelerating fa ...
#
#
# 🔮 Generating persona 33 of 500...
#
# An actuary at a specialty insurance firm, I design capital models for capped claim-count products where the number of covered events per period is inherently bounded by policy terms. Regulatory data provides dependable estimates of the mean and variance but leaves the distribution’s shape underdetermined, so for solvency and stress testing I require a conservative tail measure that avoids parametr ...
#
#
# 🔮 Generating persona 34 of 500...
#
# An operations research analyst for a pediatric hospital network, this person manages equitable on‑call rotations and clinic staffing, regularly translating fluctuating team presence into proportional workload shares. Their commute often involves driving colleagues between the main campus and satellite clinics, with daily headcounts varying by shift mix and procedure schedules, so they treat drivin ...
#
#
# 🔮 Generating persona 35 of 500...
#
# A Guidance, Navigation, and Control engineer on a reusable launch vehicle program, I am responsible for deriving thrust schedules that meet strict terminal state and timing requirements while staying within propulsion limits and conserving propellant. The digital flight computer executes updates at a fixed rate, so I prototype discrete-time models to translate engine throttle authority into comman ...
#
#
# 🔮 Generating persona 36 of 500...
#
# As the Academic Timetabling Lead at a public polytechnic, this professional translates program plans and accreditation contact-hour requirements into a weekly grid of fixed teaching blocks shared across twelve departments. They reconcile cohort overlaps from common first-year sequences, cross-listed offerings, and shared instructors, while honoring faculty contracts, adjunct availability windows,  ...
#
#
# 🔮 Generating persona 37 of 500...
#
# An engineering operations manager at a mid-sized SaaS consultancy, this professional runs the quarterly staffing cycle that places in-house programmers onto client engagements under strict delivery, skill, and compliance constraints. They design the process end-to-end: collecting ranked project preferences, validating skills against project requirements, and translating those rankings into a cost  ...
#
#
# 🔮 Generating persona 38 of 500...
#
# As a guidance, navigation, and control engineer for a reusable booster program, I write the onboard thrust scheduler that must hit a commanded touchdown point and velocity at engine cutoff while staying within tight propellant margins. Our flight computer runs a discrete-time controller synchronized to the IMU at fixed steps, and our throttle valves act nearly bang-bang at small duty cycles, so I  ...
#
#
# 🔮 Generating persona 39 of 500...
#
# As the production planning lead at a regional confectionery manufacturer, they run the weekly S&OP cycle and reconcile supplier-confirmed allocations of sugar, cocoa, and dairy with bills of materials for dozens of SKUs. Promotions and wholesale price tiers make some lines far more lucrative per case, and finance expects a mix that delivers the top-line while procurement manages tight import quota ...
#
#
# 🔮 Generating persona 40 of 500...
#
# An operations planner at a small aftermarket auto-parts manufacturer, trained as an industrial engineer with a stint in cost accounting, is accountable for weekly build plans that align shop capacities with margin targets. Their day revolves around converting time studies from machining, heat treat, and assembly cells into routings, validating labor-hour ceilings with supervisors, and marrying the ...
#
#
# 🔮 Generating persona 41 of 500...
#
# A senior operations planner at a fine foods company, this professional owns the seasonal build plan for curated gift baskets, translating sales commitments into feasible weekly schedules under tight labor and capacity constraints. Trained in industrial engineering and applied optimization, they balance regular staffing rosters with overtime premiums, aligning HR hour caps and union rules with the  ...
#
#
# 🔮 Generating persona 42 of 500...
#
# As the logistics optimization lead at a U.S. grain trading firm, they run the soybean shipping program that links inland terminals to Gulf and Pacific Northwest ports and onward to domestic crush plants or export vessels under fixed delivery windows. Their remit covers securing rail, truck, and barge capacity, managing elevator throughput and storage, negotiating tariffs and fuel surcharges, and m ...
#
#
# 🔮 Generating persona 43 of 500...
#
# A foot courier for a same-day lab pickup service on the east side, their assignments require threading the midtown grid under rush-hour foot traffic while hitting strict delivery windows. Construction zones, building security lines, and one-way plaza flows block cut-throughs and eastbound access on key segments, leaving practical choices at each intersection to continue north or shift west toward  ...
#
#
# 🔮 Generating persona 44 of 500...
#
# An operations research engineer in a rail network capacity team builds constraint solvers that allocate trains to tracks and time slots without conflicts and must justify algorithmic choices to dispatch and planning stakeholders. To validate branching heuristics, symmetry-breaking cuts, and propagation strength before touching live timetables, they keep a CI suite of model problems, and a classic  ...
#
#
# 🔮 Generating persona 45 of 500...
#
# As the production planning manager at a regional paper converting plant, they own the weekly cut plan for two high-speed rewinders that turn 3.2-meter parent rolls into customer-specific widths. Their day starts with pulling live demand from the ERP, mapping SKUs by width, and reconciling due dates, trim-loss targets, and knife-change constraints, then choosing from a library of feasible patterns  ...
#
#
# 🔮 Generating persona 46 of 500...
#
# An operations planning manager in a powertrain components division, trained in industrial engineering and managerial accounting, owns the monthly build plan that aligns shop capacity, vendor terms, and commercial commitments. They coordinate machine center hour budgets, incorporate an outsourced first machining step with a tiered standard/overtime labor rate, and reconcile contract batch commitmen ...
#
#
# 🔮 Generating persona 47 of 500...
#
# A municipal transportation safety engineer calibrates advisory stopping-distance charts for school zones using data from controlled braking tests across varied speeds, pavements, and weather conditions. Integrating thousands of radar and LIDAR readings with field logs, this role emphasizes a physics-consistent quadratic relationship while applying absolute-error loss to counter driver variability  ...
#
#
# 🔮 Generating persona 48 of 500...
#
# An operations planning engineer on a regional transmission operator’s day-ahead desk designs and runs unit-commitment optimization for a mixed portfolio of gas turbines, coal units, hydro releases, and intermittent renewables. Trained in operations research and energy economics, this engineer encodes each resource’s availability, minimum stable output, maximum capability, no-load cost, incremental ...
#
#
# 🔮 Generating persona 49 of 500...
#
# A construction estimator specializing in digital quantity takeoffs is reviewing a warehouse renovation plan where the main floorplate is split by a column line and a mezzanine edge into four bays. Three bays have area callouts needed for pricing concrete polishing and coatings, but one tag is missing and the dimension strings didn’t survive the CAD export, leaving no direct lengths to pull. With a ...
#
#
# 🔮 Generating persona 50 of 500...
#
# As a regional sales operations manager for a medical device firm, they coordinate quarterly in-person visits across a dozen hospital accounts spread over several states and are accountable for keeping travel spend and time away from clinics within strict targets. Company policy requires all road trips to start and end at the distribution hub where demo kits and temperature-controlled samples are i ...
#
#
# 🔮 Generating persona 51 of 500...
#
# An intermodal planning analyst at a private terminal operator, responsible for aligning block-train arrivals with weekly service strings and berth windows, and for negotiating short-term crane rentals and union gangs under a tight equipment budget. With a background in vessel stowage planning and yard strategy, they build monthly operating plans that balance rail unloading programs against yard oc ...
#
#
# 🔮 Generating persona 52 of 500...
#
# As the production planning manager for a division making precision auto components, they own the monthly mix plan that balances machine-center calendars, routing times, and commercial commitments. With an industrial engineering background and a stint in cost accounting, they translate routings and price lists into contribution margins and model the mix in a linear program, capturing internal capac ...
#
#
# 🔮 Generating persona 53 of 500...
#
# As the master scheduler at a high-mix aerospace machining facility, with prior experience as a CNC programmer and an industrial engineering degree, this professional owns the daily conversion of routings into executable machine timelines across mills, lathes, CMMs, heat-treat, and anodize cells. Accountable for quoted lead times and overtime budgets, they balance setup families, fixture availabili ...
#
#
# 🔮 Generating persona 54 of 500...
#
# The police department’s workforce planning manager oversees duty rosters, overtime control, and adherence to collective bargaining terms that require tours spanning two consecutive shifts, while accounting for per-shift start costs tied to briefings, equipment issuance, and vehicle deployment. With operations research training and experience implementing patrol scheduling systems, this manager tra ...
#
#
# 🔮 Generating persona 55 of 500...
#
# As Director of Academic Planning in a college of engineering, they build term-by-term degree maps that keep cohorts’ workloads manageable while honoring institutional lower and upper thresholds on credits and course counts each term. With an operations research background, they convert prerequisite chains and policy constraints into optimization models, tuning them to flatten peak term burden and  ...
#
#
# 🔮 Generating persona 56 of 500...
#
# A neuropsychology clinician in an outpatient rehabilitation program designs structured interventions to rebuild visuospatial planning, sequencing, and cognitive flexibility for clients recovering from stroke or traumatic brain injury. Sessions use a grid-based number path puzzle that exploits eight-directional adjacency and stepwise progression as a controllable challenge, with parameters like gri ...
#
#
# 🔮 Generating persona 57 of 500...
#
# An operations research specialist embedded in a mid-sized electronics assembly plant’s planning team, this person owns the master production schedule and capacity planning across machining, soldering, coating, and test work centers. With an industrial engineering background, they translate ERP routings (standard times per operation), labor calendars, and contribution margins into optimization mode ...
#
#
# 🔮 Generating persona 58 of 500...
#
# An operations manager for a chamber ensemble with a background in industrial engineering, they are responsible for building rehearsal blocks that align player call times with the specific instrumentation of each piece while honoring union rules and budget constraints. After years coordinating film scoring sessions where musicians are contracted by the minute and paid for idle time, they brought mi ...
#
#
# 🔮 Generating persona 59 of 500...
#
# A metrology engineer at a medical device manufacturer producing continuous glucose monitors, I am responsible for the calibration scheme that ties sensor electrical output to laboratory-certified glucose concentrations across multiple test points. Regulatory acceptance hinges on keeping the maximum measurement error under strict thresholds rather than optimizing average accuracy, so my workflow ce ...
#
#
# 🔮 Generating persona 60 of 500...
#
# As the plant metallurgist responsible for the melt shop’s charge mixes, I translate customer specs and mill certification requirements into heat recipes that hit tight carbon bands and nickel ceilings while honoring purchasing contracts and inventory limits on alloys. My background in industrial engineering and metallurgical process control led me to build optimization models that align furnace ca ...
#
#
# 🔮 Generating persona 61 of 500...
#
# A procurement analyst at an industrial robotics integrator, responsible for weekly buy plans on complex bills of materials, regularly manages dozens of components sourced from distributors like Mouser, Digi‑Key, McMaster, and specialty sensor suppliers, each with distinct pricing, freight terms, and account discounts. To protect project margins on fixed‑price installations, the analyst builds cost ...
#
#
# 🔮 Generating persona 62 of 500...
#
# An enterprise operations research manager for a multinational services firm, this professional leads post-merger organizational design and site strategy, blending corporate real estate, HR mobility, and finance to rebalance internal departments across a handful of candidate hubs. Their models quantify city-specific incentive packages and productivity potential, incorporate collaboration graphs to  ...
#
#
# 🔮 Generating persona 63 of 500...
#
# A production planning lead at a Tier‑1 auto components plant, this professional owns the monthly build plan that aligns OEM contracts, machine capacity, and margin targets. With routings that specify run-hours per batch across CNC cells, stamping presses, and heat-treat lines, and standard machine-hour rates supplied by finance, they translate sales commitments and floor quantities from account ma ...
#
#
# 🔮 Generating persona 64 of 500...
#
# A production planning and operations analyst at a small automotive spares manufacturer, they own the monthly S&OP and master schedule spanning CNC machining, stamping, heat treatment, grinding, and plating. Trained in industrial engineering with hands-on experience in time studies and routing standards, they convert shop-level worker-hour norms and bottleneck calendars into an optimization model t ...
#
#
# 🔮 Generating persona 65 of 500...
#
# A control systems engineer in an electric vehicle battery program, responsible for calibrating the battery management system, models admissible operating points for current, voltage, and thermal limits with linear envelopes derived from qualification and safety standards. To choose a nominal setpoint that remains resilient to sensor noise, load spikes, and cell aging, they compute the Chebyshev ce ...
#
#
# 🔮 Generating persona 66 of 500...
#
# A treasury operations lead at a multinational marketplace, this professional manages daily foreign exchange across regulated corridors, translating disparate wallet balances from overnight sales into a single settlement currency for supplier payouts. Capital controls in several jurisdictions impose per-currency conversion caps and reporting thresholds, so they design executable playbooks that sequ ...
#
#
# 🔮 Generating persona 67 of 500...
#
# I lead mine planning and optimization for a mid-tier producer with multiple leases in one district, building the annual operating plan and the life-of-asset schedule that feeds the processing plant. My remit spans selecting the mix of sites to run under a cap on concurrent operations, setting production levels within each pit’s throughput limit, and coordinating with metallurgy to hit a tight blen ...
#
#
# 🔮 Generating persona 68 of 500...
#
# An operations research engineer embedded in the production planning group of a mid-sized discrete manufacturer, accountable for translating sales targets and maintenance calendars into executable master schedules. Their remit spans S&OP, capacity loading across a heterogeneous machine fleet, and inventory policy, so they consolidate routing times per SKU, planned outages from the maintenance team, ...
#
#
# 🔮 Generating persona 69 of 500...
#
# As Director of Preconstruction and Portfolio Strategy at a design-build contractor, this professional owns the annual bid/no-bid and start sequencing decisions for a pipeline of school modernizations, logistics warehouses, and hospital additions. They must align gross margin targets with cash flow, bonding capacity, and the availability of superintendents, project managers, and specialty crews, wh ...
#
#
# 🔮 Generating persona 70 of 500...
#
# A production planning analyst at a folding-carton printer, I orchestrate gang-run impositions where multiple food and pet-food SKUs share the same thin board mother sheet, coordinating prepress, plate burning, and press capacity. My remit is to allocate the fixed number of slots on each aluminum plate—sometimes repeating a high-volume SKU across multiple slots—so purchase orders are fulfilled whil ...
#
#
# 🔮 Generating persona 71 of 500...
#
# An operations planning lead at a boutique PC assembler, responsible for the master production schedule and monthly S&OP, oversees how constrained assembly lines meet channel commitments across variable demand cycles. With a background in industrial engineering and experience implementing finite-capacity MRP, they model trade-offs among regular-shift throughput, negotiated overtime premiums, and ti ...
#
#
# 🔮 Generating persona 72 of 500...
#
# A supply chain and operations planning analyst at Wild Sports, trained in industrial engineering, oversees the monthly S&OP process and the handoff to factory scheduling. They integrate BOM-level material consumption, on-hand inventories, and supplier commitments with sales’ demand ceilings, then partner with finance to convert selling prices and variable costs into unit contribution margins. Draw ...
#
#
# 🔮 Generating persona 73 of 500...
#
# As the performance marketing lead at Custom Tees, they manage acquisition across paid web channels and are accountable for budget efficiency and audience composition. Drawing on a background in econometrics and ad operations, they design an optimization framework to allocate click buys across different ad formats and publishers, using partner age split estimates, cost per 1000 clicks, inventory ca ...
#
#
# 🔮 Generating persona 74 of 500...
#
# As Workforce Planning & Analytics Lead at a heavy‑equipment manufacturer, they blend industrial engineering and HR finance to steer the labor transition tied to automation and a softer order book. They translate engineering roadmaps and sales plans into skill mix targets, model tenure‑based attrition with elevated first‑year loss for new recruits, and quantify costs for retraining, limited externa ...
#
#
# 🔮 Generating persona 75 of 500...
#
# An assessment design lead at a national testing organization, they assemble large-scale exam booklets from a shared item bank under strict content, security, and equating requirements. Their job is to orchestrate multi-form rotations so items have consistent exposure, cross-form linkages are preserved through controlled co-appearance patterns for IRT scaling, and proctoring logistics are manageabl ...
#
#
# 🔮 Generating persona 76 of 500...
#
# As Workforce Planning and Analytics Lead in a unionized manufacturer rolling out CNC cells and robotics, I translate commissioning schedules and a softening order book into multi-year staffing mixes that tilt toward skilled and semi-skilled roles. With a background in operations research and HR policy, I maintain cohort attrition models that spike in year one, calibrate a recruitment pipeline boun ...
#
#
# 🔮 Generating persona 77 of 500...
#
# An operations research manager at a consumer electronics plant oversees the master production plan that ties monthly shipment commitments to line capacity, workforce rosters, and warehouse constraints. With a background in industrial engineering and years in production control, they understand how abrupt volume swings drive overtime, changeover complexity, and equipment wear, while excess output i ...
#
#
# 🔮 Generating persona 78 of 500...
#
# Serving as the manufacturing finance lead at a multi-line OEM, they own the monthly build plan and margin forecast, translating sales commitments into a feasible mix that respects machine availability and working capital gates. Prior roles in industrial engineering and FP&A taught them to quantify throughput, repair downtime paybacks, and cash conversion differences across SKUs, so their planning  ...
#
#
# 🔮 Generating persona 79 of 500...
#
# An operations research manager in the distribution strategy group of a national grocery chain, responsible for deciding where to open, expand, or mothball regional distribution centers as the store footprint shifts. With a background in industrial engineering and stints in carrier procurement, they run network design studies that convert store-level demand forecasts into aggregated zones, map lane ...
#
#
# 🔮 Generating persona 80 of 500...
#
# A bakery operations planner for a busy patisserie chain, they oversee ingredient allocation, batch sizing, and oven sequencing to meet daily output targets without overruns. Marketing commitments set a demand ratio favoring one flavor, while supplier delivery caps and procurement budgets constrain butter and flour, making every batch decision consequential. Because each croissant type occupies ove ...
#
#
# 🔮 Generating persona 81 of 500...
#
# A logistics lead for a touring automotive demo program, they coordinate manufacturer fleets, time slots, insurance rules, and crew to keep test-drive lanes moving at major venue stops. With an industrial engineering background in high-throughput scheduling, they design preference-driven sign-up workflows that translate attendee model interests, license class constraints, and EV charging windows in ...
#
#
# 🔮 Generating persona 82 of 500...
#
# An operations research lead at a national kidney paired donation program, embedded across multiple transplant centers, converts HLA typing, ABO compatibility, and virtual crossmatch data into a weekly directed compatibility graph. They run an integer program to select disjoint 2- and 3-way cycles and non-simultaneous chains subject to OR block availability, cold ischemia limits, center participati ...
#
#
# 🔮 Generating persona 83 of 500...
#
# A nursing workforce planning lead at a multi-service hospital, they transitioned from charge nurse duties into operations after completing certification in health systems engineering, where they specialized in cyclic rostering and capacity planning. Their remit spans night-shift coverage across med-surg, telemetry, and step-down units, balancing union rules on consecutive nights, mandated rest, an ...
#
#
# 🔮 Generating persona 84 of 500...
#
# As the Network Design Manager for a national home goods retailer, I lead the annual distribution footprint review that decides which regional DCs to operate and how to route store and e‑commerce demand. Trained in industrial engineering and operations research and coming from a 3PL where I negotiated contracts with fixed facility fees, minimum throughput commitments, and lane-based handling charge ...
#
#
# 🔮 Generating persona 85 of 500...
#
# A senior resource planning analyst at the State Energy Office, trained as a power systems engineer with a graduate focus in energy economics and prior experience on the regional ISO’s long-term planning team, leads the state’s multi-year capacity expansion docket. Tasked with translating the official load forecast into a financeable build schedule under legislative and reliability constraints, thi ...
#
#
# 🔮 Generating persona 86 of 500...
#
# A senior operations research specialist in DEC’s systems manufacturing planning group, this professional owns the quarterly build plan for the general‑purpose and workstation product families, translating sales commitments and product line constraints into a profit‑focused production mix. They synthesize CPU allocations affected by internal supplier issues, disk drive forecasts with uncertainty ba ...
#
#
# 🔮 Generating persona 87 of 500...
#
# Traffic engineering lead at a global content delivery network, responsible for converting hourly demand forecasts into routing intents across a directed backbone that includes transit and peering links with distinct tariffs and hard capacity limits. With a background in operations research and IP/MPLS, they maintain a controller that ingests flow telemetry, contract costs, and SLO constraints, the ...
#
#
# 🔮 Generating persona 88 of 500...
#
# A regional operations planner for a coastal concessions company, this professional oversees the weekly rostering of a high-traffic popsicle stand and satellite carts, translating footfall forecasts, weather volatility, and festival calendars into repeatable staffing templates. Trained in industrial engineering and workforce planning at a quick-service franchisor, they specialize in cyclic schedule ...
#
#
# 🔮 Generating persona 89 of 500...
#
# A supply network optimization lead at a global vaccine manufacturer is responsible for pushing surge volumes from a central fill‑finish facility to outbreak hotspots without breaking the cold chain. They model lanes, transshipment depots, airport slots, customs checkpoints, and truck capacities as a directed network in Python, using operations research tools to compute the highest feasible through ...
#
#
# 🔮 Generating persona 90 of 500...
#
# As the equipment logistics manager for a high-volume ski resort rental center, they oversee the daily matching of guests to a finite fleet under constraints like binding ranges, boot compatibility, and maintenance status. To streamline fittings and cut refund rates, they embedded a batch assignment routine in the reservation system that scores each potential match by the absolute gap between a gue ...
#
#
# 🔮 Generating persona 91 of 500...
#
# As the operations analyst for a regional food bank’s nutrition programs, I assemble monthly food bundles that must satisfy state dietary benchmarks while staying under tight grant budgets. My role involves maintaining a live catalog of market-available foods with vendor prices and lab-verified nutrient profiles, then using linear optimization tools to translate those data into purchase quantities  ...
#
#
# 🔮 Generating persona 92 of 500...
#
# An operations research manager in the corporate strategy team of a multinational with a London headquarters, this professional is accountable for the firm’s location strategy and enterprise cost modeling. They integrate HR hiring pipelines, government incentives, real estate lease obligations, and inter-department communication volumes into a mixed-integer optimization framework to evaluate feasib ...
#
#
# 🔮 Generating persona 93 of 500...
#
# A melt-shop planner and procurement lead at an aerospace casting foundry translates certified chemistry requirements into practical furnace charge recipes. Each production run demands balancing narrow windows for Ni, Cr, Co, Mo, and Ti against supplier quotes for master alloys, pure metals, and in-house returns, with batch size, inventory, and traceability constraints always in play. Drawing on me ...
#
#
# 🔮 Generating persona 94 of 500...
#
# An operations research engineer at a warehouse automation firm, I design routing logic for vertical shuttle robots that traverse stacked storage grids to pick one tote per level under strict lateral-movement constraints imposed by rail switching and collision avoidance. Each shelf position carries a dynamic priority score derived from SKU value, due dates, and handling risk, so my models select a  ...
#
#
# 🔮 Generating persona 95 of 500...
#
# An operations analyst in a humanitarian logistics unit coordinates emergency water shipments assembled in austere environments, where fill levels vary because portable bottling rigs lack fine calibration. Donor agreements and local relief protocols require each receiving team to get identical bottle counts and equivalent total volume, and compliance forbids decanting or rebalancing, so the analyst ...
#
#
# 🔮 Generating persona 96 of 500...
#
# A resource planning and dispatch coordinator at a small electric utility, this professional oversees day-ahead scheduling across a mix of gas turbines, small hydro, and battery-backed solar feeding several municipal load centers. Their remit blends economics and engineering: translating wheeling tariffs, loss factors, and contractual service obligations into a cost matrix, enforcing plant capaciti ...
#
#
# 🔮 Generating persona 97 of 500...
#
# As the lead capacity planner for a regional cold-chain distributor, I allocate hundreds of temperature-sensitive orders each night across three refrigerated trailers bound for different hubs. Each order carries a distinct weight and handling time, and my mandate is to build three manifests so no single trailer becomes the bottleneck against driver hours-of-service and dock curfews. I built a Pytho ...
#
#
# 🔮 Generating persona 98 of 500...
#
# An operations research analyst embedded in an auto parts division, I own the monthly production mix plan that aligns sales commitments, machine calendars, and cost targets. My role blends routings and standard times from engineering with hourly run costs and availability from maintenance, including a flexible machining cell where two adjacent stations share pooled capacity that I must model explic ...
#
#
# 🔮 Generating persona 99 of 500...
#
# As the Resource Management Office lead at a professional services firm, this person orchestrates quarterly staffing across client portfolios under strict margin targets. Trained in operations research and procurement, they build models that weigh retainer and onboarding costs for activating external consultants against deploying in-house specialists whose workload is capped by utilization policy.  ...
#
#
# 🔮 Generating persona 100 of 500...
#
# A procurement and localization lead for the Summer Games manages contracts for translators and interpreters across competition venues, broadcast, and athlete services. With a fixed language mandate from National Olympic Committees and a capped budget, they compile a vetted pool of linguists, audit credentials and sports terminology expertise, and map each translator’s coverage to event requirement ...
#
#
# 🔮 Generating persona 101 of 500...
#
# A network design analyst for a national home goods retailer, they lead the annual review of the distribution footprint and advise on which candidate sites should be activated or retired. With a background in operations research and freight procurement, they convert store demand forecasts, throughput limits, labor availability, and carrier lane rates into a Gurobi mixed-integer model that evaluates ...
#
#
# 🔮 Generating persona 102 of 500...
#
# Serving as the commodity merchandising manager for a regional cooking-oil wholesaler, they oversee a single leased warehouse with hard capacity limits and per-period carrying charges, buying from a refiner at a fixed contract price while releasing stock to independent grocers at market-derived prices that swing with harvest and import costs. Compliance mandates a rotation that opens the planning w ...
#
#
# 🔮 Generating persona 103 of 500...
#
# A reliability engineer at a medical device company ensures infusion pump flow sensors are calibrated across operating ranges. Field trials produce paired reference flows and sensor outputs with occasional spikes from air bubbles or tubing disturbances, making a robust calibration essential for regulatory audits and dose accuracy guarantees written in terms of absolute error. To meet those obligati ...
#
#
# 🔮 Generating persona 104 of 500...
#
# A humanitarian logistics planner for a nonprofit coordinates cargo manifests for chartered flights into short, rough airstrips, where payload weight, volume, center-of-gravity limits, and fuel trade-offs tightly constrain what can be loaded. Trained in industrial engineering and operations research, they build and maintain binary optimization tools that convert warehouse data—dimensions, mass, col ...
#
#
# 🔮 Generating persona 105 of 500...
#
# A supply chain network planner for a nationwide beverage bottler, they own the monthly flow plan linking plants, co-packers, and regional distribution centers. Their remit includes aligning production schedules with replenishment targets, honoring carrier volume commitments and dock calendars, and containing freight spend amid volatile fuel surcharges. They build lane-level models in a TMS and Gur ...
#
#
# 🔮 Generating persona 106 of 500...
#
# An industrial engineering and production planning lead at an auto components division, they own the monthly product-mix and capacity allocation across milling, stamping, and finishing cells. With training in operations research, they maintain a linear programming model that integrates per-hour machine operating costs, machine-specific monthly hour caps, and batch pricing from sales, while explicit ...
#
#
# 🔮 Generating persona 107 of 500...
#
# As the incident response lead for a global fintech’s hybrid cloud, I own the containment playbooks and the capacity plan for both our central malware-scanning farm and the on-endpoint agent fleet. My background is in operations research, so in parallel with coordinating the SOC, I translate containment choices into resource-allocation models that respect our change-control rule that each enclave i ...
#
#
# 🔮 Generating persona 108 of 500...
#
# As the production planning manager for a driveline and braking components division at a tier-one supplier, I own the monthly master schedule that balances contracted build requirements, machine-center capacity, and contribution margins. With an industrial engineering background and a stint in cost accounting, I translate routings and standard hours across CNC lathes, broaches, grinders, and heat-t ...
#
#
# 🔮 Generating persona 109 of 500...
#
# ...
#
#
# 🔮 Generating persona 466 of 500...
#
# A constraint programming specialist responsible for an airline’s crew assignment optimizer maintains MiniZinc models to enforce training and equipment diversity rules, with 0 used as the sentinel for unassigned duties. Their role involves defining custom global constraints that count distinct active categories in rosters while integrating with a legacy interface where relational operators are enco ...
#
#
# 🔮 Generating persona 467 of 500...
#
# A staff applied scientist at a workforce planning platform, they build constraint-based models that assign gig workers to multi-skill projects under tight service levels. Their daily work encodes worker skill tokens and project requirement tokens as variable arrays, with business rules that demand complete coverage of all required tokens by chosen assignments and careful tracking of overlap from e ...
#
#
# 🔮 Generating persona 468 of 500...
#
# A workforce scheduling analyst at a regional airline, they design daily crew rosters where each flight leg must be staffed by a distinct pilot while minimizing penalties from fatigue rules, seniority premiums, and union preferences embedded in a cost matrix. They prototype these assignments in MiniZinc, relying on global constraints to enforce unique placements and built-in array/matrix predicates ...
#
#
# 🔮 Generating persona 469 of 500...
#
# A constraint programming engineer at a crew scheduling software firm, they model assignment matrices linking crews to flight sequences and use symmetry‑breaking to keep the search tractable. To reduce equivalent permutations, they implement double‑lex ordering across rows and columns and are building a custom propagator that preserves nondecreasing domains while interacting cleanly with global con ...
#
#
# 🔮 Generating persona 470 of 500...
#
# A timetable optimization specialist for a large university, they build MiniZinc/OR-Tools models that assign courses to rooms under stringent operational and compliance requirements, including audit trails for which lecture slots use regulated room categories (wet labs, accessible spaces, broadcast studios). Their responsibilities demand clean channeling between integer room choices and set-valued  ...
#
#
# 🔮 Generating persona 471 of 500...
#
# An operations research analyst in a semiconductor fabrication plant builds constraint-programming models to allocate wafer lots to tool families while limiting the number of equipment groups brought online to reduce changeovers and qualification overhead. Their daily work involves partitioning process steps and candidate tools into resource classes, encoding a count of which classes actually recei ...
#
#
# 🔮 Generating persona 472 of 500...
#
# An operations research engineer on a large e-commerce fulfillment team, they build constraint models that assign thousands of SKUs and delivery zones to third-party partners. Each unique partner activated in a plan carries onboarding and integration fees, so they encode a set-based cost that sums the weights of the distinct partners referenced by assignment variables to capture consolidation-versu ...
#
#
# 🔮 Generating persona 473 of 500...
#
# A quality assurance engineer for a retail feedback kiosk validates a microservice that summarizes four customer ratings captured per transaction, each restricted to integers from 1 to 10. Their test plans focus on confirming the API returns the true extremes from the observed quartet, handling ties, duplicates, and boundary scenarios like uniform inputs or mixes of lowest and highest allowable val ...
#
#
# 🔮 Generating persona 474 of 500...
#
# An operations research engineer at a regional utility, they build optimization models for demand response events where thousands of smart thermostats and water heaters are dispatched in short intervals. Their mandate is to keep aggregate load shifts within contractual bounds over rolling windows so feeders stay stable and market penalties are avoided, translating device-level decisions into intege ...
#
#
# 🔮 Generating persona 475 of 500...
#
# A physical design engineer at a semiconductor firm, this person leads early floorplanning for mixed-signal SoCs where vendor macros arrive with multiple legal footprints—often unions of rectilinear regions due to guard rings, power domains, and routing channels—organized into performance and aspect-ratio families. They must select one footprint per macro and place all macros within the die boundar ...
#
#
# 🔮 Generating persona 476 of 500...
#
# A data quality engineer at a marketplace platform is responsible for validating deduplication and cardinality metrics on buyer–seller interaction logs. For regression suites, they generate compact edge lists where each row is a (buyer_id, seller_id) composite key, tuning duplicates and variations so the distinct composite count aligns with the target used by downstream analytics. This work involve ...
#
#
# 🔮 Generating persona 477 of 500...
#
# A constraint programming specialist in a retail assortment optimization team, they translate merchandising preferences into MiniZinc models where each candidate pair of items (drawn from a table of permitted orderings) is represented by attribute vectors that must satisfy a conditional lexicographic relation. To keep business policy switches manageable, they encapsulate the comparison as an operat ...
#
#
# 🔮 Generating persona 478 of 500...
#
# A reliability engineer at a satellite communications firm, they validate forward error correction modules and the associated control codebooks used by modems across varying channel conditions. Their test harnesses generate discrete configuration vectors for encoders and interleavers, and they enforce a minimum separation between pairs so decoders aren’t presented with near-duplicates that mask sen ...
#
#
# 🔮 Generating persona 479 of 500...
#
# As the scheduling lead for a research lab’s GPU cluster, I allocate hundreds of concurrent training runs under a hard data center power cap and cooling windows while keeping priority projects on track. With an operations research background, I model each run as a sequence of checkpointed segments that reserve a fixed number of GPUs per slice, incorporate blackout periods for maintenance and on-cal ...
#
#
# 🔮 Generating persona 480 of 500...
#
# A warehouse slotting engineer at a high-volume e-commerce fulfillment center, they assign bin positions for flash-sale items so each campaign occupies a single uninterrupted run of location identifiers while ensuring bins aren’t shared across SKUs. They maintain MiniZinc models integrated with the WMS to encode these placement rules, calibrate search strategies for rapid re-optimization during inb ...
#
#
# 🔮 Generating persona 481 of 500...
#
# A constraint programming engineer at a supply chain analytics firm, they maintain a catalog of modeling patterns that consultants reuse for audits and quality plans, emphasizing parity, coverage, and cardinality constraints. To validate new propagators and teach branching heuristics, they built a compact 4x6 binary-grid satisfiability case with even-parity requirements and mandatory coverage acros ...
#
#
# 🔮 Generating persona 482 of 500...
#
# A compiler backend engineer for embedded DSPs, they design register shuffles that remap live variables into physical registers within strict cycle budgets. Because the microarchitecture exposes only adjacent swaps, they rely on measuring minimal swap counts and permutation parity to determine whether a remap is feasible in a single pass, constructing distinct index arrays and computing inversion c ...
#
#
# 🔮 Generating persona 483 of 500...
#
# A knowledge-representation engineer in a zoological park’s operations group, they design the rule-based planner that allocates enclosures, transport protocols, and enrichment schedules by encoding default behaviors with explicit exceptions in a defeasible OWL/ASP stack. Their responsibilities include building taxonomic rules that keepers can trust during intake, so they maintain unit tests featuri ...
#
#
# 🔮 Generating persona 484 of 500...
#
# A quantitative economist in a city policy lab tasked with building comparative wealth indices across neighborhoods encodes pilot datasets as 4x4 adjacency matrices to reason about ordering constraints between units. To keep rankings logically coherent for dashboards and audits, this person enforces non-reflexive, one-way relationships, expressed both as the standard order-theoretic condition and a ...
#
#
# 🔮 Generating persona 485 of 500...
#
# A constraint programming engineer at an optimization software company, they maintain the MiniZinc predicate library and its regression tests used by clients in scheduling and routing. Their job requires crafting minimal models that stress strict versus non-strict argmax/argmin semantics, ensuring tie behavior is explicit and compatible with all_different across solver backends. To catch off-by-one ...
#
#
# 🔮 Generating persona 486 of 500...
#
# A constraint programming instructor in an applied optimization lab designs MiniZinc assignments that teach modular arithmetic, cyclic indexing, and declarative thinking through compact, solver-verifiable models. To illustrate wrap-around behavior and parameter recovery without heavy datasets, they use a classic rotation cipher on a ten-character code over the 26-letter alphabet, pairing a shift de ...
#
#
# 🔮 Generating persona 487 of 500...
#
# A university lecturer in constraint programming, they design and auto-grade MiniZinc labs that train students to model relational structures with small, fully specified datasets. To build a robust assessment pipeline, they ported the Marriott–Stuckey nine-person family example into MiniZinc, encoding father and mother facts as compact arrays, attaching ages, and defining reusable predicates for ki ...
#
#
# 🔮 Generating persona 488 of 500...
#
# A university instructor in constraint programming is developing a lab exercise that teaches set variables, predicate design, and reified booleans using MiniZinc. To keep search tractable while still demonstrating propagation, they frame a small bounded model that characterizes primality through divisor counting and a companion set of divisors. The assignment requires interpretable output—selected  ...
#
#
# 🔮 Generating persona 489 of 500...
#
# As a backend developer for a word-game platform, they build the pipeline that generates jumble and cryptogram challenges by producing fair, non-spoiling rearrangements of letters. For QA and analytics, the service outputs the source token, its rearranged form, and a metric counting positions that remained unchanged, and the goal is to minimize that count while maintaining unbiased randomness. Tour ...
#
#
# 🔮 Generating persona 490 of 500...
#
# A constraint programming specialist in an operations research team, they author MiniZinc templates and train colleagues to encode iterative relationships using arrays. To make index dependencies and propagation tangible in a solver-agnostic setting, they craft a compact sequence module seeded with 1 and 1, parameterized by an input length, and include it in onboarding materials and continuous inte ...
#
#
# 🔮 Generating persona 491 of 500...
#
# An agricultural operations analyst for a dairy cooperative, they design pen layouts and auction lots across n×n grids of stalls where animals carry sequential tag numbers. Biosecurity and traceability policies require moving animals in runs of n consecutive tags, while feeding and transport plans demand equal totals per row and column, so their scheduling models target the grid’s magic constant. T ...
#
#
# 🔮 Generating persona 492 of 500...
#
# I engineer static analysis tools for safety-critical embedded software, translating loop semantics into constraint systems that our SMT backend can check. To exercise termination proofs and array-bound reasoning under parity-driven state transitions, I use the Collatz iteration as a compact benchmark, modeling the state vector with a conservative triple-n capacity and asserting per-step invariants ...
#
#
# 🔮 Generating persona 493 of 500...
#
# A constraint-programming engineer in an industrial optimization team, they maintain MiniZinc models that capture how replicated modules compound capacity across a fixed number of stages, which mathematically requires raising a decision-variable base to a constant exponent. To keep models solver-friendly and avoid nonlinear black boxes, they implement a deterministic integer-power predicate usable  ...
#
#
# 🔮 Generating persona 494 of 500...
#
# A quantitative optimization engineer at a supply-chain software vendor, they maintain modeling templates that shuttle between CP/SAT and pure IP backends depending on client licenses and infrastructure. Their responsibilities include encoding small binary decision grids—such as 5×5 allocation boards—into compact integer vectors consumed by downstream feasibility checks and KPI dashboards. In CP bu ...
#
#
# 🔮 Generating persona 495 of 500...
#
# A computer science lecturer overseeing an introductory systems course maintains an autograder that enforces C memory limits on student assignments, including a lab where trainees loop through integers, collect factors in an array sized to half the input plus one, and set a flag indicating primality. Because the microcontroller toolchain expects specific identifiers, they standardize 'divisor' and  ...
#
#
# 🔮 Generating persona 496 of 500...
#
# A formal verification engineer in a semiconductor company’s secure-boot team, they are tasked with proving the correctness of low-level diagnostics that exercise arithmetic operations and bitwise masks during processor bring-up. To generate exhaustive self-check vectors and corner cases across multiple word sizes, they model the diagnostic’s transformation in MiniZinc and use constraint solving to ...
#
#
# 🔮 Generating persona 497 of 500...
#
# An operations researcher at a rail scheduling platform maintains MiniZinc models that convert raw timetables and crew rosters into solvable decision structures. Their job centers on a compact utilities layer that safely clones 1‑D and 2‑D integer arrays and sets used across scenarios, asserting index alignment and size compatibility so base data—train‑block matrices, duty vectors, and permissible  ...
#
#
# 🔮 Generating persona 498 of 500...
#
# A constraint-programming specialist at a logistics optimization group, they prototype MiniZinc models to validate combinatorial bounds used in routing and crew-assignment heuristics, where factorial terms serve as quick sanity checks for permutation counts and branch-limit estimates. Because some training datasets must run across different back ends, they maintain a small library of utility snippe ...
#
#
# 🔮 Generating persona 499 of 500...
#
# A backend engineer at a K–12 edtech company, they maintain the math microservice that generates dynamic number theory exercises for classrooms running on low-power devices. Teachers expect both a list of prime values for practice and an aggregate count for instant feedback, so the engineer implements a lightweight primality routine that checks divisibility only up to each candidate’s square root t ...
#
#
# 🔮 Generating persona 500 of 500...
#
# An operations researcher in a metropolitan transit authority, they design synchronization plans for rolling stock maintenance, platform slots, and crew rotations that recur on different cycles with fixed offsets. Their workflow translates those periodic requirements into residue classes so the earliest feasible timestamp satisfies every cyclic constraint simultaneously, and MiniZinc serves as thei ...
#
#
# ✅ Successfully generated and saved all personas:
# 📂 generated_personas\personas.json
# 📂 generated_personas\personas.txt

# %%
# =========================================================
# Step 3 (ChatGPT-only version): Generate JSON + Python solutions
# =========================================================

import os
import json
import re
import time
from openai import OpenAI
from dotenv import load_dotenv

# Load API key
load_dotenv()

AZURE_API_KEY = os.getenv("OPENAI_API_KEY")
AZURE_ENDPOINT = "https://oai-preprod-canadaeast-001.openai.azure.com" # your resource
API_VERSION = "" # example; use the version your resource supports
DEPLOYMENT_NAME = "gpt-5" # your Azure deployment name
  
if not (AZURE_ENDPOINT and AZURE_API_KEY and DEPLOYMENT_NAME):  
    raise RuntimeError("Missing one of AZURE_OPENAI_ENDPOINT, AZURE_OPENAI_API_KEY, or AZURE_OPENAI_DEPLOYMENT.")
  
# Only keep a custom client if you truly need it (e.g., corporate proxy/CA)  
http_client = httpx.Client(timeout=300.0)
  
client = OpenAI(  
    api_key=AZURE_API_KEY,  
    base_url=f"{AZURE_ENDPOINT}/openai/v1",          # note the /v1  
    default_query={"api-version": API_VERSION},      # Azure API version routing  
    http_client=http_client,  
)

# Load personas created in Step 2
with open("generated_personas/personas.json", "r",encoding="utf-8") as f:
    personas = json.load(f)

# Ensure output directories
os.makedirs("generated_problems", exist_ok=True)
os.makedirs("generated_solutions", exist_ok=True)

# =====================================================================
# PROMPTS
# =====================================================================

from string import Template

json_prompt_template = Template("""You are an expert in Operations Research and Constraint Programming.
Given the following persona, produce a strictly valid JSON object describing an advanced real-world optimization problem.

Persona:
$persona

Return ONLY a valid JSON that matches EXACTLY this schema:

{
  "Problem": {
    "Title": "Concise title",
    "Formal Problem Statement": "Detailed natural-language description",
    "Objective": "Clear optimization objective",
    "DecisionVariables": ["List and describe variables"],
    "Constraints": ["At least 3 explicit mathematical constraints"],
    "Parameters": ["Define parameters and constants"],
    "ModelType": "MILP / LP / MINLP / CP / other",
    "Complexity": "Why the problem is advanced",
    "ExpectedOutput": "What the model should return"
  }
}

Rules:
- Output ONLY the JSON.
- The JSON MUST be valid and parseable by python json.loads().
""")

python_prompt_template = Template("""You are an expert in mathematical optimization using Python and all constraint/optimization modeling packages.
Given the following JSON problem, write a complete executable Python script using the appropriate constraint/optimization modeling python package/module.

Rules:
- Import the appropriate package/module based on the appropriate method needed to execute and solve the python script successfully.
- Create model.
- Define decision variables with correct types.
- Add and represent the objective function accurately.
- Add all constraints explicitly.
- Include a small numeric example instance so the script runs immediately.
- After optimization/constraint is satisfied, print model status, objective value, and all variable values.
- Code must be returned INSIDE a ```python fenced block.

JSON Problem:
$json_text

Return ONLY the Python code inside a fenced ```python block.
""")

# =====================================================================
# Helper functions
# =====================================================================

def call_chatgpt(prompt, model="gpt-5", temperature=1):
    """Wrapper with retry logic."""
    for _ in range(3):
        try:
            resp = client.chat.completions.create(
                model=model,
                messages=[{"role": "user", "content": prompt}],
                temperature=temperature
            )
            return resp.choices[0].message.content
        except Exception as e:
            print("⚠️ ChatGPT API error:", e)
            time.sleep(2)
    return None


def extract_json(text):
    """Extract valid JSON from text."""
    if not text:
        return None
    text = text.strip()

    # Try direct load
    try:
        return json.loads(text)
    except:
        pass

    # Try to salvage largest {} block
    matches = re.findall(r"\{[\s\S]*\}", text)
    if matches:
        largest = max(matches, key=len)
        try:
            return json.loads(largest)
        except:
            return None
    return None


def extract_python(text):
    """Extract python code from ```python``` fenced block."""
    if not text:
        return None
    m = re.search(r"```python([\s\S]*?)```", text, re.DOTALL)
    if m:
        return m.group(1).strip()
    return None

# =====================================================================
# MAIN LOOP
# =====================================================================

for i, persona_obj in enumerate(personas, start=1):
    persona_text = persona_obj.get("persona", "")
    print(f"\n🧩 Persona {i}/{len(personas)} — generating JSON using ChatGPT")

    # ---------------------------------------------------------
    # 1) JSON GENERATION
    # ---------------------------------------------------------
    json_prompt = json_prompt_template.substitute(persona=persona_text)
    json_output = call_chatgpt(json_prompt)

    raw_json_path = f"generated_problems/problem_{i}_raw.txt"
    with open(raw_json_path, "w", encoding="utf-8") as f:
        f.write(json_output or "")

    print(f"📄 Saved raw ChatGPT JSON to {raw_json_path}")

    parsed_json = extract_json(json_output)

    if parsed_json:
        json_path = f"generated_problems/problem_{i}.json"
        with open(json_path, "w", encoding="utf-8") as f:
            json.dump(parsed_json, f, indent=2)
        print(f"✅ Parsed JSON saved to {json_path}")
    else:
        print(f"❌ JSON parsing failed for persona {i}. Check raw file.")
        continue

    # ---------------------------------------------------------
    # 2) PYTHON / GUROBI CODE GENERATION
    # ---------------------------------------------------------
    print(f"💻 Generating Python Gurobi model for Persona {i} using ChatGPT")

    python_prompt = python_prompt_template.substitute(
        json_text=json.dumps(parsed_json, indent=2)
    )
    python_output = call_chatgpt(python_prompt)

    raw_py_path = f"generated_solutions/solution_{i}_raw.txt"
    with open(raw_py_path, "w", encoding="utf-8") as f:
        f.write(python_output or "")

    print(f"📄 Saved raw Python output to {raw_py_path}")

    python_code = extract_python(python_output)

    if python_code:
        py_path = f"generated_solutions/solution_{i}.py"
        with open(py_path, "w", encoding="utf-8") as f:
            f.write(python_code)
        print(f"✅ Extracted Python script saved to {py_path}")
    else:
        print(f"⚠️ Could not extract code for persona {i} — inspect raw file.")

print("\n🎉 Done! All problems + solutions generated using ChatGPT.")
# Out:
# 🧩 Persona 1/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_1_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_1.json
# 💻 Generating Python Gurobi model for Persona 1 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_1_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_1.py
#
# 🧩 Persona 2/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_2_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_2.json
# 💻 Generating Python Gurobi model for Persona 2 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_2_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_2.py
#
# 🧩 Persona 3/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_3_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_3.json
# 💻 Generating Python Gurobi model for Persona 3 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_3_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_3.py
#
# 🧩 Persona 4/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_4_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_4.json
# 💻 Generating Python Gurobi model for Persona 4 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_4_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_4.py
#
# 🧩 Persona 5/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_5_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_5.json
# 💻 Generating Python Gurobi model for Persona 5 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_5_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_5.py
#
# 🧩 Persona 6/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_6_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_6.json
# 💻 Generating Python Gurobi model for Persona 6 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_6_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_6.py
#
# 🧩 Persona 7/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_7_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_7.json
# 💻 Generating Python Gurobi model for Persona 7 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_7_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_7.py
#
# 🧩 Persona 8/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_8_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_8.json
# 💻 Generating Python Gurobi model for Persona 8 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_8_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_8.py
#
# 🧩 Persona 9/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_9_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_9.json
# 💻 Generating Python Gurobi model for Persona 9 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_9_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_9.py
#
# 🧩 Persona 10/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_10_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_10.json
# 💻 Generating Python Gurobi model for Persona 10 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_10_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_10.py
#
# 🧩 Persona 11/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_11_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_11.json
# 💻 Generating Python Gurobi model for Persona 11 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_11_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_11.py
#
# 🧩 Persona 12/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_12_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_12.json
# 💻 Generating Python Gurobi model for Persona 12 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_12_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_12.py
#
# 🧩 Persona 13/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_13_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_13.json
# 💻 Generating Python Gurobi model for Persona 13 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_13_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_13.py
#
# 🧩 Persona 14/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_14_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_14.json
# 💻 Generating Python Gurobi model for Persona 14 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_14_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_14.py
#
# 🧩 Persona 15/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_15_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_15.json
# 💻 Generating Python Gurobi model for Persona 15 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_15_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_15.py
#
# 🧩 Persona 16/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_16_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_16.json
# 💻 Generating Python Gurobi model for Persona 16 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_16_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_16.py
#
# 🧩 Persona 17/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_17_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_17.json
# 💻 Generating Python Gurobi model for Persona 17 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_17_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_17.py
#
# 🧩 Persona 18/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_18_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_18.json
# 💻 Generating Python Gurobi model for Persona 18 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_18_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_18.py
#
# 🧩 Persona 19/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_19_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_19.json
# 💻 Generating Python Gurobi model for Persona 19 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_19_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_19.py
#
# 🧩 Persona 20/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_20_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_20.json
# 💻 Generating Python Gurobi model for Persona 20 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_20_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_20.py
#
# 🧩 Persona 21/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_21_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_21.json
# 💻 Generating Python Gurobi model for Persona 21 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_21_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_21.py
#
# 🧩 Persona 22/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_22_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_22.json
# 💻 Generating Python Gurobi model for Persona 22 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_22_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_22.py
#
# 🧩 Persona 23/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_23_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_23.json
# 💻 Generating Python Gurobi model for Persona 23 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_23_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_23.py
#
# 🧩 Persona 24/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_24_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_24.json
# 💻 Generating Python Gurobi model for Persona 24 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_24_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_24.py
#
# 🧩 Persona 25/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_25_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_25.json
# 💻 Generating Python Gurobi model for Persona 25 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_25_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_25.py
#
# 🧩 Persona 26/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_26_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_26.json
# 💻 Generating Python Gurobi model for Persona 26 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_26_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_26.py
#
# 🧩 Persona 27/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_27_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_27.json
# 💻 Generating Python Gurobi model for Persona 27 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_27_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_27.py
#
# 🧩 Persona 28/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_28_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_28.json
# 💻 Generating Python Gurobi model for Persona 28 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_28_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_28.py
#
# 🧩 Persona 29/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_29_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_29.json
# 💻 Generating Python Gurobi model for Persona 29 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_29_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_29.py
#
# 🧩 Persona 30/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_30_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_30.json
# 💻 Generating Python Gurobi model for Persona 30 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_30_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_30.py
#
# 🧩 Persona 31/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_31_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_31.json
# 💻 Generating Python Gurobi model for Persona 31 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_31_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_31.py
#
# 🧩 Persona 32/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_32_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_32.json
# 💻 Generating Python Gurobi model for Persona 32 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_32_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_32.py
#
# 🧩 Persona 33/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_33_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_33.json
# 💻 Generating Python Gurobi model for Persona 33 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_33_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_33.py
#
# 🧩 Persona 34/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_34_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_34.json
# 💻 Generating Python Gurobi model for Persona 34 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_34_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_34.py
#
# 🧩 Persona 35/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_35_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_35.json
# 💻 Generating Python Gurobi model for Persona 35 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_35_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_35.py
#
# 🧩 Persona 36/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_36_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_36.json
# 💻 Generating Python Gurobi model for Persona 36 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_36_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_36.py
#
# 🧩 Persona 37/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_37_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_37.json
# 💻 Generating Python Gurobi model for Persona 37 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_37_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_37.py
#
# 🧩 Persona 38/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_38_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_38.json
# 💻 Generating Python Gurobi model for Persona 38 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_38_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_38.py
#
# 🧩 Persona 39/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_39_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_39.json
# 💻 Generating Python Gurobi model for Persona 39 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_39_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_39.py
#
# 🧩 Persona 40/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_40_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_40.json
# 💻 Generating Python Gurobi model for Persona 40 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_40_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_40.py
#
# 🧩 Persona 41/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_41_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_41.json
# 💻 Generating Python Gurobi model for Persona 41 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_41_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_41.py
#
# 🧩 Persona 42/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_42_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_42.json
# 💻 Generating Python Gurobi model for Persona 42 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_42_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_42.py
#
# 🧩 Persona 43/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_43_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_43.json
# 💻 Generating Python Gurobi model for Persona 43 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_43_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_43.py
#
# 🧩 Persona 44/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_44_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_44.json
# 💻 Generating Python Gurobi model for Persona 44 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_44_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_44.py
#
# 🧩 Persona 45/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_45_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_45.json
# 💻 Generating Python Gurobi model for Persona 45 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_45_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_45.py
#
# 🧩 Persona 46/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_46_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_46.json
# 💻 Generating Python Gurobi model for Persona 46 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_46_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_46.py
#
# 🧩 Persona 47/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_47_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_47.json
# 💻 Generating Python Gurobi model for Persona 47 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_47_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_47.py
#
# 🧩 Persona 48/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_48_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_48.json
# 💻 Generating Python Gurobi model for Persona 48 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_48_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_48.py
#
# 🧩 Persona 49/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_49_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_49.json
# 💻 Generating Python Gurobi model for Persona 49 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_49_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_49.py
#
# 🧩 Persona 50/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_50_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_50.json
# 💻 Generating Python Gurobi model for Persona 50 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_50_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_50.py
#
# 🧩 Persona 51/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_51_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_51.json
# 💻 Generating Python Gurobi model for Persona 51 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_51_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_51.py
#
# 🧩 Persona 52/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_52_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_52.json
# 💻 Generating Python Gurobi model for Persona 52 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_52_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_52.py
#
# 🧩 Persona 53/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_53_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_53.json
# 💻 Generating Python Gurobi model for Persona 53 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_53_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_53.py
#
# 🧩 Persona 54/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_54_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_54.json
# 💻 Generating Python Gurobi model for Persona 54 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_54_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_54.py
#
# 🧩 Persona 55/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_55_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_55.json
# 💻 Generating Python Gurobi model for Persona 55 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_55_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_55.py
#
# 🧩 Persona 56/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_56_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_56.json
# 💻 Generating Python Gurobi model for Persona 56 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_56_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_56.py
#
# 🧩 Persona 57/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_57_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_57.json
# 💻 Generating Python Gurobi model for Persona 57 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_57_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_57.py
#
# 🧩 Persona 58/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_58_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_58.json
# 💻 Generating Python Gurobi model for Persona 58 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_58_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_58.py
#
# 🧩 Persona 59/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_59_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_59.json
# 💻 Generating Python Gurobi model for Persona 59 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_59_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_59.py
#
# 🧩 Persona 60/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_60_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_60.json
# 💻 Generating Python Gurobi model for Persona 60 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_60_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_60.py
#
# 🧩 Persona 61/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_61_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_61.json
# 💻 Generating Python Gurobi model for Persona 61 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_61_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_61.py
#
# 🧩 Persona 62/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_62_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_62.json
# 💻 Generating Python Gurobi model for Persona 62 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_62_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_62.py
#
# 🧩 Persona 63/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_63_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_63.json
# 💻 Generating Python Gurobi model for Persona 63 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_63_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_63.py
#
# 🧩 Persona 64/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_64_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_64.json
# 💻 Generating Python Gurobi model for Persona 64 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_64_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_64.py
#
# 🧩 Persona 65/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_65_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_65.json
# 💻 Generating Python Gurobi model for Persona 65 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_65_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_65.py
#
# 🧩 Persona 66/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_66_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_66.json
# 💻 Generating Python Gurobi model for Persona 66 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_66_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_66.py
#
# 🧩 Persona 67/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_67_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_67.json
# 💻 Generating Python Gurobi model for Persona 67 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_67_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_67.py
#
# 🧩 Persona 68/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_68_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_68.json
# 💻 Generating Python Gurobi model for Persona 68 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_68_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_68.py
#
# 🧩 Persona 69/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_69_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_69.json
# 💻 Generating Python Gurobi model for Persona 69 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_69_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_69.py
#
# 🧩 Persona 70/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_70_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_70.json
# 💻 Generating Python Gurobi model for Persona 70 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_70_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_70.py
#
# 🧩 Persona 71/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_71_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_71.json
# 💻 Generating Python Gurobi model for Persona 71 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_71_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_71.py
#
# 🧩 Persona 72/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_72_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_72.json
# 💻 Generating Python Gurobi model for Persona 72 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_72_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_72.py
#
# 🧩 Persona 73/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_73_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_73.json
# 💻 Generating Python Gurobi model for Persona 73 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_73_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_73.py
#
# 🧩 Persona 74/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_74_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_74.json
# 💻 Generating Python Gurobi model for Persona 74 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_74_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_74.py
#
# 🧩 Persona 75/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_75_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_75.json
# 💻 Generating Python Gurobi model for Persona 75 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_75_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_75.py
#
# 🧩 Persona 76/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_76_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_76.json
# 💻 Generating Python Gurobi model for Persona 76 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_76_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_76.py
#
# 🧩 Persona 77/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_77_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_77.json
# 💻 Generating Python Gurobi model for Persona 77 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_77_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_77.py
#
# 🧩 Persona 78/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_78_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_78.json
# 💻 Generating Python Gurobi model for Persona 78 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_78_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_78.py
#
# 🧩 Persona 79/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_79_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_79.json
# 💻 Generating Python Gurobi model for Persona 79 using ChatGPT
# 📄 Saved raw Python output to generated_solutions/solution_79_raw.txt
# ✅ Extracted Python script saved to generated_solutions/solution_79.py
#
# 🧩 Persona 80/500 — generating JSON using ChatGPT
# 📄 Saved raw ChatGPT JSON to generated_problems/problem_80_raw.txt
# ✅ Parsed JSON saved to generated_problems/problem_80.json
# 💻 Generating Python Gurobi model for Persona 80 using ChatGPT
